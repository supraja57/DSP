# %% [markdown]
# <a href="https://colab.research.google.com/github/supraja57/DSP/blob/master/Day15(10_06_20).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##Import the required packages

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")
tips#tips is a dataframe present in memory
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Plots using
# 1.Pandas
# 2.Matplotlib
# 3.seaborn

# %%
tips['total_bill'].hist()

# %%
plt.hist(tips['total_bill'],bins = 5)##hist is a method name            bins is number of parts to be divided in the range   by default no.of bins is 10
# Out:
# (array([ 49., 119.,  50.,  19.,   7.]),
#  array([ 3.07 , 12.618, 22.166, 31.714, 41.262, 50.81 ]),
#  <a list of 5 Patch objects>)

# %%
sns.distplot(tips['total_bill'],kde=False)#distribution plot

# %%
sns.relplot("total_bill","tip",data=tips)

# %%
sns.relplot("total_bill","tip",data=tips,hue= 'smoker')

# %%
sns.relplot("total_bill","tip",data=tips,col= 'smoker')

# %%
sns.relplot("total_bill","tip",data=tips,hue = 'smoker',col= 'sex')

# %%
sns.relplot("total_bill","tip",data=tips,hue = 'smoker',col= 'sex',style='smoker')#Relative plot

# %%
sns.__version__##to check version
# Out:
# '0.10.1'

# %%
pd.__version__
# Out:
# '1.0.4'

# %%
sns.scatterplot("total_bill","tip",data = tips,hue='smoker')

# %%
sns.scatterplot("total_bill","tip",data = tips)

# %%
sns.relplot("total_bill","tip",data = tips,kind = 'line')

# %%
#categorical plot

# %%
sns.catplot("total_bill",'tip',data = tips,hue='smoker')

# %%
sns.catplot("day",'tip',data=tips)

# %%
sns.catplot("day",'tip',data=tips,kind = 'swarm')

# %%
sns.catplot("day",'tip',data=tips,kind = 'swarm',hue = 'smoker')

# %%
sns.catplot("day",'tip',data=tips,kind = 'swarm',hue = 'smoker',col = 'sex')

# %%
sns.catplot("day",'tip',data = tips,kind = 'box')

# %%
sns.catplot("day",'tip',data = tips,kind = 'box',hue = 'sex')

# %%
sns.catplot("day",data = tips,kind = 'count')

# %%
sns.catplot("day",data = tips,kind = 'count',hue = 'smoker')

# %%
sns.catplot("day",data = tips,kind = 'count',hue = 'smoker',hue_order=['No','Yes'])

# %%
sns.boxplot(tips['tip'])

# %%
sns.boxplot(y=tips['tip'])

# %%
sns.boxplot(y=tips['tip'],hue = 'smoker',data= tips)

# %%
sns.countplot(tips['day'])

# %%
##Distrubution plots

# %%
sns.distplot(tips['tip'])#kde is kernel density estimation         line is kde    other is histogram

# %%
sns.distplot(tips['tip'],kde=False)

# %%
sns.distplot(tips['tip'],hist=False)

# %%
sns.distplot(tips['tip'],kde=False,rug = True)

# %%
sns.distplot(tips['tip'],rug = True)

# %%
###jOINT PLOT

# %%
sns.jointplot("total_bill",'tip',data = tips)#upper is hist for bill and side is hist for tip         plot is scatterplot

# %%
sns.jointplot("total_bill",'tip',data = tips,kind = 'kde')

# %%
t,tb
t,t
tb,s    are combinations of numerical columns
tb,t
s,t

s,tb

# %%
tips.dtypes!='category'
# Out:
# total_bill     True
# tip            True
# sex           False
# smoker        False
# day           False
# time          False
# size           True
# dtype: bool

# %%
num_col=tips.columns[tips.dtypes!='category']

# %%
for i in range(len(num_col)):
  for j in range(len(num_col)):
    print(num_col[i],num_col[j])
# Out:
# total_bill total_bill
# total_bill tip
# total_bill size
# tip total_bill
# tip tip
# tip size
# size total_bill
# size tip
# size size

# %%
val = 1
for i in range(len(num_col)):
  for j in range(len(num_col)):
    plt.subplot(3,3,val)
    plt.scatter(tips[num_col[i]],tips[num_col[j]])
    plt.title(num_col[i]+'_'+num_col[j])
    val =+ 1
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   after removing the cwd from sys.path.

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='smoker')

# %%
sns.pairplot(tips,hue = 'sex')

# %%
sns.pairplot(tips,hue = 'sex',kind = 'reg')

# %%
sns.set(style='whitegrid')
sns.regplot("tip","total_bill",data = tips)

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr())
